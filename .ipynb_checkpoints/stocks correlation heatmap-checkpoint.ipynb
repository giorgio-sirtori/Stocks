# %%
#77bRza8YW__th7Twr1ry
#import libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import pandas_datareader.data as web
from datetime import datetime
import os
# %env ALPHAVANTAGE_API_KEY = NTN3D6P6LIMZ6A2Q#alpha advantage api key
# Out:
# env: ALPHAVANTAGE_API_KEY=NTN3D6P6LIMZ6A2Q#alpha advantage api key

# %%
ptf = ['PLTR','KTOS','PDD','BABA']
ptf_df = []

# %%
for stock in ptf:
    ptf_df.append(web.DataReader(stock, "av-daily-adjusted", 
                                    start=datetime(2015,1, 1), 
                                    end=datetime(2021, 1, 16),api_key=os.getenv('ALPHAVANTAGE_API_KEY')))

# %%
ptf_df[0]
# Out:
#              open     high    low  close  adjusted close     volume  \
# 2020-09-30  10.00  11.4200   9.11   9.50            9.50  338584433
# 2020-10-01   9.69  10.1000   9.23   9.46            9.46  124297587
# 2020-10-02   9.06   9.2800   8.94   9.20            9.20   55018343
# 2020-10-05   9.43   9.4900   8.92   9.03            9.03   36316878
# 2020-10-06   9.04  10.1800   8.90   9.90            9.90   90864039
# ...           ...      ...    ...    ...             ...        ...
# 2021-01-11  24.61  26.6000  24.31  25.93           25.93   32608983
# 2021-01-12  26.34  26.4200  25.51  26.18           26.18   26688460
# 2021-01-13  25.71  27.4298  25.13  25.50           25.50   51216556
# 2021-01-14  25.45  25.6200  24.37  24.92           24.92   32908003
# 2021-01-15  26.26  28.0000  25.46  25.64           25.64   92285513
#
#             dividend amount  split coefficient
# 2020-09-30              0.0                1.0
# 2020-10-01              0.0                1.0
# 2020-10-02              0.0                1.0
# 2020-10-05              0.0                1.0
# 2020-10-06              0.0                1.0
# ...                     ...                ...
# 2021-01-11              0.0                1.0
# 2021-01-12              0.0                1.0
# 2021-01-13              0.0                1.0
# 2021-01-14              0.0                1.0
# 2021-01-15              0.0                1.0
#
# [75 rows x 8 columns]
