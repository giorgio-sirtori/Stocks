# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as web
from datetime import datetime
import os
# %env ALPHAVANTAGE_API_KEY = NTN3D6P6LIMZ6A2Q#alpha advantage api key
# Out:
# env: ALPHAVANTAGE_API_KEY=NTN3D6P6LIMZ6A2Q#alpha advantage api key

# %%
ptf = ['PLTR','KTOS','PDD','BABA']
ptf_df = []

# %%
for stock in ptf:
    ptf_df.append(web.DataReader(stock, "av-daily-adjusted", 
                                    start=datetime(2015,1, 1), 
                                    end=datetime(2021, 1, 16),api_key=os.getenv('ALPHAVANTAGE_API_KEY')))

# %%
for stock in ptf_df:
    stock['pct_change'] = stock['adjusted close'].pct_change()
    stock['log_ret'] = np.log(stock['adjusted close']) - np.log(stock['adjusted close'].shift(1))
    stock['rolling_ma_20'] = stock['adjusted close'].rolling(window=20).mean()

# %%
ptf_df[0]
# Out:
#              open     high    low  close  adjusted close     volume  \
# 2020-09-30  10.00  11.4200   9.11   9.50            9.50  338584433
# 2020-10-01   9.69  10.1000   9.23   9.46            9.46  124297587
# 2020-10-02   9.06   9.2800   8.94   9.20            9.20   55018343
# 2020-10-05   9.43   9.4900   8.92   9.03            9.03   36316878
# 2020-10-06   9.04  10.1800   8.90   9.90            9.90   90864039
# ...           ...      ...    ...    ...             ...        ...
# 2021-01-11  24.61  26.6000  24.31  25.93           25.93   32608983
# 2021-01-12  26.34  26.4200  25.51  26.18           26.18   26688460
# 2021-01-13  25.71  27.4298  25.13  25.50           25.50   51216556
# 2021-01-14  25.45  25.6200  24.37  24.92           24.92   32908003
# 2021-01-15  26.26  28.0000  25.46  25.64           25.64   92285513
#
#             dividend amount  split coefficient  pct_change   log_ret  \
# 2020-09-30              0.0                1.0         NaN       NaN
# 2020-10-01              0.0                1.0   -0.004211 -0.004219
# 2020-10-02              0.0                1.0   -0.027484 -0.027869
# 2020-10-05              0.0                1.0   -0.018478 -0.018651
# 2020-10-06              0.0                1.0    0.096346  0.091982
# ...                     ...                ...         ...       ...
# 2021-01-11              0.0                1.0    0.028968  0.028557
# 2021-01-12              0.0                1.0    0.009641  0.009595
# 2021-01-13              0.0                1.0   -0.025974 -0.026317
# 2021-01-14              0.0                1.0   -0.022745 -0.023008
# 2021-01-15              0.0                1.0    0.028892  0.028483
#
#             rolling_ma_20
# 2020-09-30            NaN
# 2020-10-01            NaN
# 2020-10-02            NaN
# 2020-10-05            NaN
# 2020-10-06            NaN
# ...                   ...
# 2021-01-11        25.9780
# 2021-01-12        25.9270
# 2021-01-13        25.8400
# 2021-01-14        25.7645
# 2021-01-15        25.7505
#
# [75 rows x 11 columns]

# %%
returns = pd.DataFrame()
i = 0
for stock in ptf_df:
    returns[ptf[i]] = stock['pct_change']
    i += 1

# %%
returns
# Out:
#                 PLTR      KTOS       PDD      BABA
# 2020-09-30       NaN -0.009250  0.006106  0.061568
# 2020-10-01 -0.004211  0.006224  0.003776 -0.013368
# 2020-10-02 -0.027484  0.011340 -0.040709 -0.006482
# 2020-10-05 -0.018478  0.020387  0.009384  0.000347
# 2020-10-06  0.096346 -0.015984  0.012765  0.014292
# ...              ...       ...       ...       ...
# 2021-01-11  0.028968 -0.007904 -0.045804 -0.037343
# 2021-01-12  0.009641  0.065250 -0.017450 -0.007785
# 2021-01-13 -0.025974 -0.011396 -0.027614  0.042996
# 2021-01-14 -0.022745  0.095101  0.014927  0.032639
# 2021-01-15  0.028892 -0.027961 -0.036231  0.001975
#
# [75 rows x 4 columns]

# %%
corr_df = returns.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
# Out:
#           PLTR      KTOS       PDD      BABA
# PLTR  1.000000  0.051680 -0.063088  0.156900
# KTOS  0.051680  1.000000  0.106346  0.038022
# PDD  -0.063088  0.106346  1.000000  0.239457
# BABA  0.156900  0.038022  0.239457  1.000000

# %%
mask = np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)] = True
#generate plot
sns.heatmap(corr_df, cmap='RdYlGn', vmax=1.0, vmin=-1.0 , mask = mask, linewidths=2.5)
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.show()
